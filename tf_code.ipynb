# %%
import os
os.chdir('/content/drive/My Drive')

# %%
# !git clone https://github.com/chenhsuanlin/3D-point-cloud-generation.git

# %%
# !tar -zxf s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz

# %%
# !pwd

# %%
# !pip install tensorflow-gpu==1.12.0
# Out:
# ...
#      |████████████████████████████████| 281.7MB 50kB/s
# ...
#      |████████████████████████████████| 3.1MB 55.1MB/s
# ...
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.12.2 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
# ...

# %%
# !dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda=9.0.176-1

# %%
os.chdir('/content/drive/My Drive/3D-point-cloud-generation')

# %%
# !sh scripts/run-finetune.sh

# %%
# !sh scripts/run-evaluate.sh
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !sh scripts/run-compute-error.sh
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import os
path = '/content/drive/My Drive/3D-point-cloud-generation_0/results_0/orig-ft_it58000/10dc303144fe5d668d1b9a1d97e2846.mat'
data = scipy.io.loadmat(path)
plt.figure(figsize=(20,20))

for i in range(24):
  plt.subplot(5,5,i+1)
  plt.imshow(data['image'][i,:,:,:])
  plt.axis('off')

plt.tight_layout()
plt.savefig('/content/drive/My Drive/3D-point-cloud-generation/images/image12.png')
plt.show()
# Out:
# (24, 1)

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import os
path = '/content/drive/My Drive/3D-point-cloud-generation_0/results_0/orig-ft_it58000/10dc303144fe5d668d1b9a1d97e2846.mat'
data = scipy.io.loadmat(path)
    
fig = plt.figure(figsize = (18,20))
for i in  range(24):
  ax =fig.add_subplot(6, 6, i+1, projection='3d')
  ax.scatter3D(data['pointcloud'][i,0][:,0],data['pointcloud'][i,0][:,1],data['pointcloud'][i,0][:,2], c='green')
  plt.axis('off')
plt.tight_layout()  
plt.show()  
plt.savefig('/content/drive/My Drive/3D-point-cloud-generation/images/image52.png')

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import os
path = '/content/drive/My Drive/3D-point-cloud-generation_0/data/03001627_testGT/3ab3c9d99fcaa66bebd676e3a69dcf6.mat'
data = scipy.io.loadmat(path)
    

#print(data)
print(data.keys())
print(data['E'].shape)
print(data['F'].shape)
print(data['V'].shape)
print(data['Vd'].shape)
#data['pointcloud'].shape
#data['__header__']
#print(data['image'].shape)
#data['pointcloud'][0][0].shape
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'E', 'F', 'V', 'Vd'])
# (462, 2)
# (307, 3)
# (156, 3)
# (100000, 3)
